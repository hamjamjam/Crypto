# %%
#find all possible pairs
symbols = ['ADA', 'AION', 'ANT', 'ARDR', 'BAT', 'BCC', 'BCH', 'BLZ', 'BNB', 'BNT', 'BTC', 'BTS', 'BUSD', 'CTXC', 'CVC', 'DAI', 'DASH', 'DATA', 'DCR', 'DENT', 'DGB', 'DNT', 'DOGE', 'ENJ', 'EOS', 'ETC', 'ETH', 'FUN', 'GTO', 'GXS', 'ICX', 'IOST', 'IOTA', 'IOTX', 'KMD', 'KNC', 'LEND', 'LINK', 'LRC', 'LSK', 'LTC', 'MANA', 'MCO', 'MITH', 'MKR', 'NANO', 'NEO', 'NMR', 'NPXS', 'NULS', 'OMG', 'ONT', 'QTUM', 'REP', 'RLC', 'SC', 'SNX', 'STORJ', 'STORM', 'STRAT', 'STX', 'THETA', 'TRX', 'TUSD', 'UTK', 'VEN', 'WAN', 'WAVES', 'WTC', 'XLM', 'XMR', 'XRP', 'XTZ', 'XZC', 'ZEC', 'ZEN', 'ZIL', 'ZRX']

def possible_pairs():
        pairs = []
        for asset_1 in symbols:
            for asset_2 in symbols:
                if not asset_1 == asset_2:
                    pairs.append([asset_1, asset_2])
        return pairs

# %%
pairs = possible_pairs()

# %%
from statsmodels.tsa.stattools import coint
import pandas as pd


def cointegrated(series_1, series_2, p_threshold=0.05):
    #return true if significantly cointegrated
    pval = coint(series_1, series_2)[1]
    print(pval)
    return pval < p_threshold

def get_close_prices(asset_1, asset_2):
    filename_1 = "Price Data/{}.csv".format(asset_1)
    df_1 = pd.read_csv(filename_1)
    
    filename_2 = "Price Data/{}.csv".format(asset_2)
    df_2 = pd.read_csv(filename_2)
    
    prices_1 = df_1['close']
    prices_2 = df_2['close']
    
    #make sure the prices are equal length
    if len(prices_1) > len(prices_2):
        prices_1 = prices_1[-len(prices_2):]
    elif len(prices_2) > len(prices_1):
        prices_2 = prices_2[-len(prices_1):]
        
    return prices_1, prices_2

def find_coint_pairs(pairs):
    selected_pairs = {}
    
    for idx, pair in enumerate(pairs):
        print(idx,'/',len(pairs))
        print("finding cointegration of {}\n".format(pair))
        asset_1 = pair[0]
        asset_2 = pair[1]
        
        prices_1, prices_2 = get_close_prices(asset_1, asset_2)
        
        if cointegrated(prices_1, prices_2):
            print("Added {}\n".format(pair))
            selected_pairs[asset_1+'|'+asset_2] = [asset_1, asset_2]
    return selected_pairs  

selected_pairs = find_coint_pairs(pairs)
# Out:
# 0 / 6006
# finding cointegration of ['ADA', 'AION']
#
# 0.7745703763720545
# 1 / 6006
# finding cointegration of ['ADA', 'ANT']
#
# 0.6306593654296039
# 2 / 6006
# finding cointegration of ['ADA', 'ARDR']
#
# 0.7562563495152834
# 3 / 6006
# finding cointegration of ['ADA', 'BAT']
#
# 0.8021010439799717
# 4 / 6006
# finding cointegration of ['ADA', 'BCC']
#
# 0.013209780207788246
# Added ['ADA', 'BCC']
#
# 5 / 6006
# finding cointegration of ['ADA', 'BCH']
#
# 0.7207063697206839
# 6 / 6006
# finding cointegration of ['ADA', 'BLZ']
#
# 0.03652800615616078
# Added ['ADA', 'BLZ']
#
# 7 / 6006
# finding cointegration of ['ADA', 'BNB']
#
# 0.9182346189730097
# 8 / 6006
# finding cointegration of ['ADA', 'BNT']
#
# 0.7018065368578004
# 9 / 6006
# finding cointegration of ['ADA', 'BTC']
#
# 0.8519143460587213
# 10 / 6006
# finding cointegration of ['ADA', 'BTS']
#
# 0.6186396551959346
# 11 / 6006
# finding cointegration of ['ADA', 'BUSD']
#
# 0.49963138348006597
# 12 / 6006
# finding cointegration of ['ADA', 'CTXC']
#
# 0.9618710350671162
# 13 / 6006
# finding cointegration of ['ADA', 'CVC']
#
# 0.8294876818685044
# 14 / 6006
# finding cointegration of ['ADA', 'DAI']
#
# 0.6485090845886696
# 15 / 6006
# finding cointegration of ['ADA', 'DASH']
#
# 0.12248812792336988
# 16 / 6006
# finding cointegration of ['ADA', 'DATA']
#
# 0.8846634522146979
# 17 / 6006
# finding cointegration of ['ADA', 'DCR']
#
# 0.8781683614524687
# 18 / 6006
# finding cointegration of ['ADA', 'DENT']
#
# 0.3281926107601454
# 19 / 6006
# finding cointegration of ['ADA', 'DGB']
#
# 0.4886107357493862
# 20 / 6006
# finding cointegration of ['ADA', 'DNT']
#
# 0.22974549188918197
# 21 / 6006
# finding cointegration of ['ADA', 'DOGE']
#
# 0.8021213893308845
# 22 / 6006
# finding cointegration of ['ADA', 'ENJ']
#
# 0.6712675819703249
# 23 / 6006
# finding cointegration of ['ADA', 'EOS']
#
# 0.1001649116503534
# 24 / 6006
# finding cointegration of ['ADA', 'ETC']
#
# 0.032973948394035474
# Added ['ADA', 'ETC']
#
# 25 / 6006
# finding cointegration of ['ADA', 'ETH']
#
# 1.1071324561557225e-06
# Added ['ADA', 'ETH']
#
# 26 / 6006
# finding cointegration of ['ADA', 'FUN']
#
# 0.6332614544592096
# 27 / 6006
# finding cointegration of ['ADA', 'GTO']
#
# 0.014831133255833883
# Added ['ADA', 'GTO']
#
# 28 / 6006
# finding cointegration of ['ADA', 'GXS']
#
# 0.8928131646448337
# 29 / 6006
# finding cointegration of ['ADA', 'ICX']
#
# 0.03752400017373548
# Added ['ADA', 'ICX']
#
# 30 / 6006
# finding cointegration of ['ADA', 'IOST']
#
# 0.8446410118515413
# 31 / 6006
# finding cointegration of ['ADA', 'IOTA']
#
# 0.052868926441845654
# 32 / 6006
# finding cointegration of ['ADA', 'IOTX']
#
# 0.8806832669369545
# 33 / 6006
# finding cointegration of ['ADA', 'KMD']
#
# 0.15975984664183945
# 34 / 6006
# finding cointegration of ['ADA', 'KNC']
#
# 0.8026377897214931
# 35 / 6006
# finding cointegration of ['ADA', 'LEND']
#
# 0.3951273308553656
# 36 / 6006
# finding cointegration of ['ADA', 'LINK']
#
# 0.34183097698492826
# 37 / 6006
# finding cointegration of ['ADA', 'LRC']
#
# 0.5784296731389688
# 38 / 6006
# finding cointegration of ['ADA', 'LSK']
#
# 0.8062699092971788
# 39 / 6006
# finding cointegration of ['ADA', 'LTC']
#
# 0.1944043815989242
# 40 / 6006
# finding cointegration of ['ADA', 'MANA']
#
# 0.9125974659117588
# 41 / 6006
# finding cointegration of ['ADA', 'MCO']
#
# 0.8308928466556574
# 42 / 6006
# finding cointegration of ['ADA', 'MITH']
#
# 1.548789009701287e-05
# Added ['ADA', 'MITH']
#
# 43 / 6006
# finding cointegration of ['ADA', 'MKR']
#
# 0.7076693298004548
# 44 / 6006
# finding cointegration of ['ADA', 'NANO']
#
# 0.10770508199059814
# 45 / 6006
# finding cointegration of ['ADA', 'NEO']
#
# 0.00014348675706137343
# Added ['ADA', 'NEO']
#
# 46 / 6006
# finding cointegration of ['ADA', 'NMR']
#
# 0.1327242330708034
# 47 / 6006
# finding cointegration of ['ADA', 'NPXS']
#
# 0.15606697551398646
# 48 / 6006
# finding cointegration of ['ADA', 'NULS']
#
# 0.0961233410580909
# 49 / 6006
# finding cointegration of ['ADA', 'OMG']
#
# 0.6293319294778191
# 50 / 6006
# finding cointegration of ['ADA', 'ONT']
#
# 0.25805959172163595
# 51 / 6006
# finding cointegration of ['ADA', 'QTUM']
#
# 0.02388612836630498
# Added ['ADA', 'QTUM']
#
# 52 / 6006
# finding cointegration of ['ADA', 'REP']
#
# 0.8561540194934424
# 53 / 6006
# finding cointegration of ['ADA', 'RLC']
#
# 0.8929774308907374
# 54 / 6006
# finding cointegration of ['ADA', 'SC']
#
# 0.7672550720112634
# 55 / 6006
# finding cointegration of ['ADA', 'SNX']
#
# 0.7605668735128104
# 56 / 6006
# finding cointegration of ['ADA', 'STORJ']
#
# 0.7134494461872624
# 57 / 6006
# finding cointegration of ['ADA', 'STORM']
#
# 0.831781879911403
# 58 / 6006
# finding cointegration of ['ADA', 'STRAT']
#
# 0.9215929601779945
# 59 / 6006
# finding cointegration of ['ADA', 'STX']
#
# 0.959370802824198
# 60 / 6006
# finding cointegration of ['ADA', 'THETA']
#
# 0.4979246044935939
# 61 / 6006
# finding cointegration of ['ADA', 'TRX']
#
# 0.11384918454580745
# 62 / 6006
# finding cointegration of ['ADA', 'TUSD']
#
# 0.9185872605411403
# 63 / 6006
# finding cointegration of ['ADA', 'UTK']
#
# 0.6311274944409802
# 64 / 6006
# finding cointegration of ['ADA', 'VEN']
#
# 0.8393933474774677
# 65 / 6006
# finding cointegration of ['ADA', 'WAN']
#
# 0.5731070917890745
# 66 / 6006
# finding cointegration of ['ADA', 'WAVES']
#
# 0.8422408442193219
# 67 / 6006
# finding cointegration of ['ADA', 'WTC']
#
# 0.747763682345947
# 68 / 6006
# finding cointegration of ['ADA', 'XLM']
#
# 0.021594968367733603
# Added ['ADA', 'XLM']
#
# 69 / 6006
# finding cointegration of ['ADA', 'XMR']
#
# 0.8834935827597177
# 70 / 6006
# finding cointegration of ['ADA', 'XRP']
#
# 0.46094964654556925
# 71 / 6006
# finding cointegration of ['ADA', 'XTZ']
#
# 0.12075910332061235
# 72 / 6006
# finding cointegration of ['ADA', 'XZC']
#
# 0.7328303535439638
# 73 / 6006
# finding cointegration of ['ADA', 'ZEC']
#
# 0.34034754433237546
# 74 / 6006
# finding cointegration of ['ADA', 'ZEN']
#
# 0.8742942374713415
# 75 / 6006
# finding cointegration of ['ADA', 'ZIL']
#
# 0.8271713976127196
# 76 / 6006
# finding cointegration of ['ADA', 'ZRX']
#
# 0.4596343806250521
# 77 / 6006
# finding cointegration of ['AION', 'ADA']
#
# 0.325769538595003
# 78 / 6006
# finding cointegration of ['AION', 'ANT']
#
# 0.4359110845082377
# 79 / 6006
# finding cointegration of ['AION', 'ARDR']
#
# 0.3630057616263094
# 80 / 6006
# finding cointegration of ['AION', 'BAT']
#
# 0.1841097812569295
# 81 / 6006
# finding cointegration of ['AION', 'BCC']
#
# 0.24548397736702704
# 82 / 6006
# finding cointegration of ['AION', 'BCH']
#
# 0.10277220804260084
# 83 / 6006
# finding cointegration of ['AION', 'BLZ']
#
# 0.40008818081842074
# 84 / 6006
# finding cointegration of ['AION', 'BNB']
#
# 0.3000475824183546
# 85 / 6006
# finding cointegration of ['AION', 'BNT']
#
# 0.24769978543012133
# 86 / 6006
# finding cointegration of ['AION', 'BTC']
#
# 0.28885117522167114
# 87 / 6006
# finding cointegration of ['AION', 'BTS']
#
# 0.044923179188120894
# Added ['AION', 'BTS']
#
# 88 / 6006
# finding cointegration of ['AION', 'BUSD']
#
# 0.3351184483584363
# 89 / 6006
# finding cointegration of ['AION', 'CTXC']
#
# 0.3060599246057768
# 90 / 6006
# finding cointegration of ['AION', 'CVC']
#
# 0.29922055692617056
# 91 / 6006
# finding cointegration of ['AION', 'DAI']
#
# 0.5048750713755954
# 92 / 6006
# finding cointegration of ['AION', 'DASH']
#
# 0.2970970796242984
# 93 / 6006
# finding cointegration of ['AION', 'DATA']
#
# 0.21546837623204323
# 94 / 6006
# finding cointegration of ['AION', 'DCR']
#
# 0.22962551878615772
# 95 / 6006
# finding cointegration of ['AION', 'DENT']
#
# 0.2572997356116928
# 96 / 6006
# finding cointegration of ['AION', 'DGB']
#
# 0.4841737680655261
# 97 / 6006
# finding cointegration of ['AION', 'DNT']
#
# 0.9264544678236165
# 98 / 6006
# finding cointegration of ['AION', 'DOGE']
#
# 0.24785174697051443
# 99 / 6006
# finding cointegration of ['AION', 'ENJ']
#
# 0.2640143205378225
# 100 / 6006
# finding cointegration of ['AION', 'EOS']
#
# 0.29938787031410286
# 101 / 6006
# finding cointegration of ['AION', 'ETC']
#
# 0.30400561436295903
# 102 / 6006
# finding cointegration of ['AION', 'ETH']
#
# 0.2977640029879811
# 103 / 6006
# finding cointegration of ['AION', 'FUN']
#
# 0.29523893801800494
# 104 / 6006
# finding cointegration of ['AION', 'GTO']
#
# 0.22769428830053606
# 105 / 6006
# finding cointegration of ['AION', 'GXS']
#
# 0.3028856042909781
# 106 / 6006
# finding cointegration of ['AION', 'ICX']
#
# 0.2811655541742107
# 107 / 6006
# finding cointegration of ['AION', 'IOST']
#
# 0.29487007725604325
# 108 / 6006
# finding cointegration of ['AION', 'IOTA']
#
# 0.2637247331803372
# 109 / 6006
# finding cointegration of ['AION', 'IOTX']
#
# 0.14067406025912715
# 110 / 6006
# finding cointegration of ['AION', 'KMD']
#
# 0.6802614828827279
# 111 / 6006
# finding cointegration of ['AION', 'KNC']
#
# 0.3960171430118363
# 112 / 6006
# finding cointegration of ['AION', 'LEND']
#
# 0.22570057506036334
# 113 / 6006
# finding cointegration of ['AION', 'LINK']
# 0.28033141884311996
# 114 / 6006
# finding cointegration of ['AION', 'LRC']
#
# 0.17912813992334664
# 115 / 6006
# finding cointegration of ['AION', 'LSK']
#
# 0.33409088881068305
# 116 / 6006
# finding cointegration of ['AION', 'LTC']
#
# 0.2958141757463106
# 117 / 6006
# finding cointegration of ['AION', 'MANA']
#
# 0.5044954229914569
# 118 / 6006
# finding cointegration of ['AION', 'MCO']
#
# 0.28314513528997304
# 119 / 6006
# finding cointegration of ['AION', 'MITH']
#
# 0.3144418227877539
# 120 / 6006
# finding cointegration of ['AION', 'MKR']
#
# 0.40355511346226036
# 121 / 6006
# finding cointegration of ['AION', 'NANO']
#
# 0.28003574847553303
# 122 / 6006
# finding cointegration of ['AION', 'NEO']
#
# 0.29142557683265924
# 123 / 6006
# finding cointegration of ['AION', 'NMR']
#
# 0.6146374499354083
# 124 / 6006
# finding cointegration of ['AION', 'NPXS']
#
# 0.2888364196831579
# 125 / 6006
# finding cointegration of ['AION', 'NULS']
#
# 0.29776950812167646
# 126 / 6006
# finding cointegration of ['AION', 'OMG']
#
# 0.30100951721002583
# 127 / 6006
# finding cointegration of ['AION', 'ONT']
#
# 0.2543470740422964
# 128 / 6006
# finding cointegration of ['AION', 'QTUM']
#
# 0.30846552054943577
# 129 / 6006
# finding cointegration of ['AION', 'REP']
#
# 0.07279729184454717
# 130 / 6006
# finding cointegration of ['AION', 'RLC']
#
# 0.16068301249083183
# 131 / 6006
# finding cointegration of ['AION', 'SC']
#
# 0.12361892716679007
# 132 / 6006
# finding cointegration of ['AION', 'SNX']
#
# 0.023966887314814462
# Added ['AION', 'SNX']
#
# 133 / 6006
# finding cointegration of ['AION', 'STORJ']
#
# 0.03361802460571362
# Added ['AION', 'STORJ']
#
# 134 / 6006
# finding cointegration of ['AION', 'STORM']
#
# 0.27647387100724796
# 135 / 6006
# finding cointegration of ['AION', 'STRAT']
#
# 0.14595130925861466
# 136 / 6006
# finding cointegration of ['AION', 'STX']
#
# 0.23803303887658328
# 137 / 6006
# finding cointegration of ['AION', 'THETA']
#
# 0.2981853429169681
# 138 / 6006
# finding cointegration of ['AION', 'TRX']
#
# 0.3173752091829304
# 139 / 6006
# finding cointegration of ['AION', 'TUSD']
#
# 0.16958078846883362
# 140 / 6006
# finding cointegration of ['AION', 'UTK']
#
# 0.7362994131552321
# 141 / 6006
# finding cointegration of ['AION', 'VEN']
#
# 0.018878200496067477
# Added ['AION', 'VEN']
#
# 142 / 6006
# finding cointegration of ['AION', 'WAN']
#
# 0.18736425624714015
# 143 / 6006
# finding cointegration of ['AION', 'WAVES']
#
# 0.28742958282598097
# 144 / 6006
# finding cointegration of ['AION', 'WTC']
#
# 0.23624298456728782
# 145 / 6006
# finding cointegration of ['AION', 'XLM']
#
# 0.1529782107862992
# 146 / 6006
# finding cointegration of ['AION', 'XMR']
#
# 0.26174312582069814
# 147 / 6006
# finding cointegration of ['AION', 'XRP']
#
# 0.2566801312342547
# 148 / 6006
# finding cointegration of ['AION', 'XTZ']
#
# 0.2937153417991894
# 149 / 6006
# finding cointegration of ['AION', 'XZC']
#
# 0.26254039079774893
# 150 / 6006
# finding cointegration of ['AION', 'ZEC']
#
# 0.3124933665020935
# 151 / 6006
# finding cointegration of ['AION', 'ZEN']
#
# 0.2124155515443633
# 152 / 6006
# finding cointegration of ['AION', 'ZIL']
#
# 0.2912524423632885
# 153 / 6006
# finding cointegration of ['AION', 'ZRX']
#
# 0.12595482094455646
# 154 / 6006
# finding cointegration of ['ANT', 'ADA']
#
# 0.8119314828424844
# 155 / 6006
# finding cointegration of ['ANT', 'AION']
#
# 0.561269116058518
# 156 / 6006
# finding cointegration of ['ANT', 'ARDR']
#
# 0.5455541221053245
# 157 / 6006
# finding cointegration of ['ANT', 'BAT']
#
# 0.0008247904254947157
# Added ['ANT', 'BAT']
#
# 158 / 6006
# finding cointegration of ['ANT', 'BCC']
#
# 0.7435217029743193
# 159 / 6006
# finding cointegration of ['ANT', 'BCH']
#
# 0.40992369455527
# 160 / 6006
# finding cointegration of ['ANT', 'BLZ']
#
# 0.15834294893666295
# 161 / 6006
# finding cointegration of ['ANT', 'BNB']
#
# 0.12584256751764328
# 162 / 6006
# finding cointegration of ['ANT', 'BNT']
#
# 0.6742989670423577
# 163 / 6006
# finding cointegration of ['ANT', 'BTC']
#
# 0.7991876441714209
# 164 / 6006
# finding cointegration of ['ANT', 'BTS']
#
# 0.045444987291829
# Added ['ANT', 'BTS']
#
# 165 / 6006
# finding cointegration of ['ANT', 'BUSD']
#
# 0.5084517812193674
# 166 / 6006
# finding cointegration of ['ANT', 'CTXC']
#
# 0.7354518715368052
# 167 / 6006
# finding cointegration of ['ANT', 'CVC']
#
# 0.6796939951285701
# 168 / 6006
# finding cointegration of ['ANT', 'DAI']
#
# 0.7412474960586798
# 169 / 6006
# finding cointegration of ['ANT', 'DASH']
#
# 0.3385104289946444
# 170 / 6006
# finding cointegration of ['ANT', 'DATA']
#
# 0.7576031018964517
# 171 / 6006
# finding cointegration of ['ANT', 'DCR']
#
# 0.6041041815837851
# 172 / 6006
# finding cointegration of ['ANT', 'DENT']
#
# 0.01788020713173812
# Added ['ANT', 'DENT']
#
# 173 / 6006
# finding cointegration of ['ANT', 'DGB']
#
# 0.7434683708549343
# 174 / 6006
# finding cointegration of ['ANT', 'DNT']
#
# 0.5987201010017829
# 175 / 6006
# finding cointegration of ['ANT', 'DOGE']
#
# 0.1189805179588288
# 176 / 6006
# finding cointegration of ['ANT', 'ENJ']
#
# 0.5736525402549085
# 177 / 6006
# finding cointegration of ['ANT', 'EOS']
#
# 0.3433362984807392
# 178 / 6006
# finding cointegration of ['ANT', 'ETC']
#
# 0.715196845582452
# 179 / 6006
# finding cointegration of ['ANT', 'ETH']
#
# 0.6865072615227419
# 180 / 6006
# finding cointegration of ['ANT', 'FUN']
#
# 0.2760849119376413
# 181 / 6006
# finding cointegration of ['ANT', 'GTO']
#
# 0.00128010266318945
# Added ['ANT', 'GTO']
#
# 182 / 6006
# finding cointegration of ['ANT', 'GXS']
#
# 0.6637683551432448
# 183 / 6006
# finding cointegration of ['ANT', 'ICX']
#
# 0.0036847846341512783
# Added ['ANT', 'ICX']
#
# 184 / 6006
# finding cointegration of ['ANT', 'IOST']
#
# 0.9511597186596907
# 185 / 6006
# finding cointegration of ['ANT', 'IOTA']
#
# 0.18046835029618002
# 186 / 6006
# finding cointegration of ['ANT', 'IOTX']
#
# 0.7971104252335438
# 187 / 6006
# finding cointegration of ['ANT', 'KMD']
#
# 0.002704324746566181
# Added ['ANT', 'KMD']
#
# 188 / 6006
# finding cointegration of ['ANT', 'KNC']
#
# 0.7618397179339669
# 189 / 6006
# finding cointegration of ['ANT', 'LEND']
#
# 0.5410036309998508
# 190 / 6006
# finding cointegration of ['ANT', 'LINK']
#
# 0.4642536760503726
# 191 / 6006
# finding cointegration of ['ANT', 'LRC']
#
# 0.322110046177308
# 192 / 6006
# finding cointegration of ['ANT', 'LSK']
#
# 0.864344441178561
# 193 / 6006
# finding cointegration of ['ANT', 'LTC']
#
# 0.7198599108771178
# 194 / 6006
# finding cointegration of ['ANT', 'MANA']
#
# 0.9813429478162342
# 195 / 6006
# finding cointegration of ['ANT', 'MCO']
#
# 0.4160843513022795
# 196 / 6006
# finding cointegration of ['ANT', 'MITH']
#
# 0.7315648150305245
# 197 / 6006
# finding cointegration of ['ANT', 'MKR']
#
# 0.8744914795809839
# 198 / 6006
# finding cointegration of ['ANT', 'NANO']
#
# 0.7685978627008566
# 199 / 6006
# finding cointegration of ['ANT', 'NEO']
#
# 0.7893051261613189
# 200 / 6006
# finding cointegration of ['ANT', 'NMR']
#
# 0.3664830955093082
# 201 / 6006
# finding cointegration of ['ANT', 'NPXS']
#
# 0.040120479146539906
# Added ['ANT', 'NPXS']
#
# 202 / 6006
# finding cointegration of ['ANT', 'NULS']
#
# 0.46506777309820946
# 203 / 6006
# finding cointegration of ['ANT', 'OMG']
#
# 0.7642323635235724
# 204 / 6006
# finding cointegration of ['ANT', 'ONT']
#
# 0.002576991660945635
# Added ['ANT', 'ONT']
#
# 205 / 6006
# finding cointegration of ['ANT', 'QTUM']
#
# 0.7594501266168519
# 206 / 6006
# finding cointegration of ['ANT', 'REP']
#
# 0.6941608931766017
# 207 / 6006
# finding cointegration of ['ANT', 'RLC']
#
# 0.7202433342217911
# 208 / 6006
# finding cointegration of ['ANT', 'SC']
#
# 0.7988002913625698
# 209 / 6006
# finding cointegration of ['ANT', 'SNX']
#
# 0.5006572961522522
# 210 / 6006
# finding cointegration of ['ANT', 'STORJ']
#
# 0.9108145446812251
# 211 / 6006
# finding cointegration of ['ANT', 'STORM']
#
# 0.3941259370216913
# 212 / 6006
# finding cointegration of ['ANT', 'STRAT']
#
# 0.6937222197492445
# 213 / 6006
# finding cointegration of ['ANT', 'STX']
#
# 0.21538384991761822
# 214 / 6006
# finding cointegration of ['ANT', 'THETA']
#
# 0.5866513865739038
# 215 / 6006
# finding cointegration of ['ANT', 'TRX']
#
# 0.040393746637836764
# Added ['ANT', 'TRX']
#
# 216 / 6006
# finding cointegration of ['ANT', 'TUSD']
#
# 0.6354643682134542
# 217 / 6006
# finding cointegration of ['ANT', 'UTK']
#
# 0.7501627974677392
# 218 / 6006
# finding cointegration of ['ANT', 'VEN']
#
# 0.3093132779299729
# 219 / 6006
# finding cointegration of ['ANT', 'WAN']
#
# 0.1355578215380805
# 220 / 6006
# finding cointegration of ['ANT', 'WAVES']
#
# 0.7798625886232631
# 221 / 6006
# finding cointegration of ['ANT', 'WTC']
#
# 0.4579674015892341
# 222 / 6006
# finding cointegration of ['ANT', 'XLM']
#
# 0.7364159482140318
# 223 / 6006
# finding cointegration of ['ANT', 'XMR']
#
# 0.3015638664012951
# 224 / 6006
# finding cointegration of ['ANT', 'XRP']
#
# 0.15937012635622327
# 225 / 6006
# finding cointegration of ['ANT', 'XTZ']
#
# 0.26153988094520514
# 226 / 6006
# finding cointegration of ['ANT', 'XZC']
#
# 0.3855314168734914
# 227 / 6006
# finding cointegration of ['ANT', 'ZEC']
#
# 0.45647560121105946
# 228 / 6006
# finding cointegration of ['ANT', 'ZEN']
#
# 0.7809502453557993
# 229 / 6006
# finding cointegration of ['ANT', 'ZIL']
#
# 0.7269599145340593
# 230 / 6006
# finding cointegration of ['ANT', 'ZRX']
# 0.2894837036036688
# 231 / 6006
# finding cointegration of ['ARDR', 'ADA']
#
# 0.47812591494810247
# 232 / 6006
# finding cointegration of ['ARDR', 'AION']
#
# 0.38443538305076774
# 233 / 6006
# finding cointegration of ['ARDR', 'ANT']
#
# 0.4786451887773271
# 234 / 6006
# finding cointegration of ['ARDR', 'BAT']
#
# 0.4017788854361568
# 235 / 6006
# finding cointegration of ['ARDR', 'BCC']
#
# 0.5747967290399855
# 236 / 6006
# finding cointegration of ['ARDR', 'BCH']
#
# 0.3716017996741038
# 237 / 6006
# finding cointegration of ['ARDR', 'BLZ']
#
# 0.43034765269042674
# 238 / 6006
# finding cointegration of ['ARDR', 'BNB']
#
# 0.1846671193732039
# 239 / 6006
# finding cointegration of ['ARDR', 'BNT']
#
# 0.4027559706239452
# 240 / 6006
# finding cointegration of ['ARDR', 'BTC']
#
# 0.3868350585451247
# 241 / 6006
# finding cointegration of ['ARDR', 'BTS']
#
# 0.39655861270769505
# 242 / 6006
# finding cointegration of ['ARDR', 'BUSD']
#
# 0.3196271186131079
# 243 / 6006
# finding cointegration of ['ARDR', 'CTXC']
#
# 0.6179814074759962
# 244 / 6006
# finding cointegration of ['ARDR', 'CVC']
#
# 0.1820404029184079
# 245 / 6006
# finding cointegration of ['ARDR', 'DAI']
#
# 0.30843649690248803
# 246 / 6006
# finding cointegration of ['ARDR', 'DASH']
#
# 0.3281317139057898
# 247 / 6006
# finding cointegration of ['ARDR', 'DATA']
#
# 0.4042245367624768
# 248 / 6006
# finding cointegration of ['ARDR', 'DCR']
#
# 0.7878685092275509
# 249 / 6006
# finding cointegration of ['ARDR', 'DENT']
#
# 0.1040483487729138
# 250 / 6006
# finding cointegration of ['ARDR', 'DGB']
#
# 0.5567481051531626
# 251 / 6006
# finding cointegration of ['ARDR', 'DNT']
#
# 0.09422851041207247
# 252 / 6006
# finding cointegration of ['ARDR', 'DOGE']
#
# 0.3811805173213181
# 253 / 6006
# finding cointegration of ['ARDR', 'ENJ']
#
# 0.3915905112350937
# 254 / 6006
# finding cointegration of ['ARDR', 'EOS']
#
# 0.18526599694199758
# 255 / 6006
# finding cointegration of ['ARDR', 'ETC']
#
# 0.34494235954850117
# 256 / 6006
# finding cointegration of ['ARDR', 'ETH']
#
# 0.5715857293438676
# 257 / 6006
# finding cointegration of ['ARDR', 'FUN']
#
# 0.3731367795207663
# 258 / 6006
# finding cointegration of ['ARDR', 'GTO']
#
# 0.16955427368175968
# 259 / 6006
# finding cointegration of ['ARDR', 'GXS']
#
# 0.10797857826721019
# 260 / 6006
# finding cointegration of ['ARDR', 'ICX']
#
# 0.33430224812739495
# 261 / 6006
# finding cointegration of ['ARDR', 'IOST']
#
# 0.4021025399533238
# 262 / 6006
# finding cointegration of ['ARDR', 'IOTA']
#
# 0.16715487990618083
# 263 / 6006
# finding cointegration of ['ARDR', 'IOTX']
#
# 0.24596044583595356
# 264 / 6006
# finding cointegration of ['ARDR', 'KMD']
#
# 0.5286952563812791
# 265 / 6006
# finding cointegration of ['ARDR', 'KNC']
#
# 0.6693569122327532
# 266 / 6006
# finding cointegration of ['ARDR', 'LEND']
#
# 0.1637869858368441
# 267 / 6006
# finding cointegration of ['ARDR', 'LINK']
#
# 0.40111116984338485
# 268 / 6006
# finding cointegration of ['ARDR', 'LRC']
#
# 0.05290920900708824
# 269 / 6006
# finding cointegration of ['ARDR', 'LSK']
#
# 0.3988103060954703
# 270 / 6006
# finding cointegration of ['ARDR', 'LTC']
#
# 0.4505423112139779
# 271 / 6006
# finding cointegration of ['ARDR', 'MANA']
#
# 0.7213023727511303
# 272 / 6006
# finding cointegration of ['ARDR', 'MCO']
#
# 0.5214426282100673
# 273 / 6006
# finding cointegration of ['ARDR', 'MITH']
#
# 0.42730051393311896
# 274 / 6006
# finding cointegration of ['ARDR', 'MKR']
#
# 0.7718570413242735
# 275 / 6006
# finding cointegration of ['ARDR', 'NANO']
#
# 0.5834224840282495
# 276 / 6006
# finding cointegration of ['ARDR', 'NEO']
#
# 0.5033701747459945
# 277 / 6006
# finding cointegration of ['ARDR', 'NMR']
#
# 0.6944523416464176
# 278 / 6006
# finding cointegration of ['ARDR', 'NPXS']
#
# 0.17292371030549886
# 279 / 6006
# finding cointegration of ['ARDR', 'NULS']
#
# 0.29264584147274325
# 280 / 6006
# finding cointegration of ['ARDR', 'OMG']
#
# 0.40455164551943323
# 281 / 6006
# finding cointegration of ['ARDR', 'ONT']
#
# 0.15653739484217238
# 282 / 6006
# finding cointegration of ['ARDR', 'QTUM']
#
# 0.29311914227392744
# 283 / 6006
# finding cointegration of ['ARDR', 'REP']
#
# 0.680513768356166
# 284 / 6006
# finding cointegration of ['ARDR', 'RLC']
#
# 0.4128556362715365
# 285 / 6006
# finding cointegration of ['ARDR', 'SC']
#
# 0.48013709339816196
# 286 / 6006
# finding cointegration of ['ARDR', 'SNX']
#
# 0.7569674844748447
# 287 / 6006
# finding cointegration of ['ARDR', 'STORJ']
#
# 0.792065469664141
# 288 / 6006
# finding cointegration of ['ARDR', 'STORM']
#
# 0.5195871548499504
# 289 / 6006
# finding cointegration of ['ARDR', 'STRAT']
#
# 0.3799693517535541
# 290 / 6006
# finding cointegration of ['ARDR', 'STX']
#
# 0.2684409329304024
# 291 / 6006
# finding cointegration of ['ARDR', 'THETA']
#
# 0.5845684572217973
# 292 / 6006
# finding cointegration of ['ARDR', 'TRX']
#
# 0.17195783568127093
# 293 / 6006
# finding cointegration of ['ARDR', 'TUSD']
#
# 0.3114892607726703
# 294 / 6006
# finding cointegration of ['ARDR', 'UTK']
#
# 0.3378469236608771
# 295 / 6006
# finding cointegration of ['ARDR', 'VEN']
#
# 0.012725581131703486
# Added ['ARDR', 'VEN']
#
# 296 / 6006
# finding cointegration of ['ARDR', 'WAN']
#
# 0.10193294119869528
# 297 / 6006
# finding cointegration of ['ARDR', 'WAVES']
#
# 0.5659252570090314
# 298 / 6006
# finding cointegration of ['ARDR', 'WTC']
#
# 0.5302517301663582
# 299 / 6006
# finding cointegration of ['ARDR', 'XLM']
#
# 0.36665458495077907
# 300 / 6006
# finding cointegration of ['ARDR', 'XMR']
#
# 0.1070679052551014
# 301 / 6006
# finding cointegration of ['ARDR', 'XRP']
#
# 0.0860316592271283
# 302 / 6006
# finding cointegration of ['ARDR', 'XTZ']
#
# 0.5871586193522453
# 303 / 6006
# finding cointegration of ['ARDR', 'XZC']
#
# 0.2873436587277858
# 304 / 6006
# finding cointegration of ['ARDR', 'ZEC']
#
# 0.2768707980937043
# 305 / 6006
# finding cointegration of ['ARDR', 'ZEN']
#
# 0.39072630835877925
# 306 / 6006
# finding cointegration of ['ARDR', 'ZIL']
#
# 0.3959495686217025
# 307 / 6006
# finding cointegration of ['ARDR', 'ZRX']
#
# 0.4930708554659808
# 308 / 6006
# finding cointegration of ['BAT', 'ADA']
#
# 0.3984579555641693
# 309 / 6006
# finding cointegration of ['BAT', 'AION']
#
# 0.6316188493745668
# 310 / 6006
# finding cointegration of ['BAT', 'ANT']
#
# 0.03004539271885827
# Added ['BAT', 'ANT']
#
# 311 / 6006
# finding cointegration of ['BAT', 'ARDR']
#
# 0.6281160217107247
# 312 / 6006
# finding cointegration of ['BAT', 'BCC']
#
# 0.2985683398313739
# 313 / 6006
# finding cointegration of ['BAT', 'BCH']
#
# 0.08458870732181778
# 314 / 6006
# finding cointegration of ['BAT', 'BLZ']
#
# 0.9042094729599884
# 315 / 6006
# finding cointegration of ['BAT', 'BNB']
#
# 0.3870990704245828
# 316 / 6006
# finding cointegration of ['BAT', 'BNT']
#
# 0.6801427058536139
# 317 / 6006
# finding cointegration of ['BAT', 'BTC']
#
# 0.3194010971003558
# 318 / 6006
# finding cointegration of ['BAT', 'BTS']
#
# 0.3984080647133156
# 319 / 6006
# finding cointegration of ['BAT', 'BUSD']
#
# 0.47950865614502086
# 320 / 6006
# finding cointegration of ['BAT', 'CTXC']
#
# 0.16957777976137134
# 321 / 6006
# finding cointegration of ['BAT', 'CVC']
#
# 0.6840854552896175
# 322 / 6006
# finding cointegration of ['BAT', 'DAI']
#
# 1.0
# 323 / 6006
# finding cointegration of ['BAT', 'DASH']
#
# 0.09733835353547365
# 324 / 6006
# finding cointegration of ['BAT', 'DATA']
#
# 0.5408216004706942
# 325 / 6006
# finding cointegration of ['BAT', 'DCR']
#
# 0.960705667064598
# 326 / 6006
# finding cointegration of ['BAT', 'DENT']
#
# 0.6995482939725088
# 327 / 6006
# finding cointegration of ['BAT', 'DGB']
#
# 0.9163897933756768
# 328 / 6006
# finding cointegration of ['BAT', 'DNT']
#
# 0.07935733174351767
# 329 / 6006
# finding cointegration of ['BAT', 'DOGE']
#
# 0.5582639448257084
# 330 / 6006
# finding cointegration of ['BAT', 'ENJ']
#
# 0.43953500409774177
# 331 / 6006
# finding cointegration of ['BAT', 'EOS']
#
# 0.412514522114495
# 332 / 6006
# finding cointegration of ['BAT', 'ETC']
#
# 0.43024041863246426
# 333 / 6006
# finding cointegration of ['BAT', 'ETH']
#
# 0.23862628763855515
# 334 / 6006
# finding cointegration of ['BAT', 'FUN']
#
# 0.6771405671274175
# 335 / 6006
# finding cointegration of ['BAT', 'GTO']
#
# 0.760119371336772
# 336 / 6006
# finding cointegration of ['BAT', 'GXS']
#
# 0.6694938750304079
# 337 / 6006
# finding cointegration of ['BAT', 'ICX']
#
# 0.5055445073931956
# 338 / 6006
# finding cointegration of ['BAT', 'IOST']
#
# 0.13521723657147866
# 339 / 6006
# finding cointegration of ['BAT', 'IOTA']
#
# 0.5351022705251371
# 340 / 6006
# finding cointegration of ['BAT', 'IOTX']
#
# 0.5764220776100691
# 341 / 6006
# finding cointegration of ['BAT', 'KMD']
#
# 0.06367740286435854
# 342 / 6006
# finding cointegration of ['BAT', 'KNC']
#
# 0.7265871639883318
# 343 / 6006
# finding cointegration of ['BAT', 'LEND']
#
# 0.876688297300899
# 344 / 6006
# finding cointegration of ['BAT', 'LINK']
#
# 0.39628810073565574
# 345 / 6006
# finding cointegration of ['BAT', 'LRC']
#
# 0.6195202198192022
# 346 / 6006
# finding cointegration of ['BAT', 'LSK']
#
# 0.5631701287834432
# 347 / 6006
# finding cointegration of ['BAT', 'LTC']
# 0.36062137250461257
# 348 / 6006
# finding cointegration of ['BAT', 'MANA']
#
# 0.8180821721364048
# 349 / 6006
# finding cointegration of ['BAT', 'MCO']
#
# 0.809398580981528
# 350 / 6006
# finding cointegration of ['BAT', 'MITH']
#
# 0.6295122623116465
# 351 / 6006
# finding cointegration of ['BAT', 'MKR']
#
# 0.9313417795756763
# 352 / 6006
# finding cointegration of ['BAT', 'NANO']
#
# 0.10504209018854982
# 353 / 6006
# finding cointegration of ['BAT', 'NEO']
#
# 0.40091080078781516
# 354 / 6006
# finding cointegration of ['BAT', 'NMR']
#
# 0.0343018425575323
# Added ['BAT', 'NMR']
#
# 355 / 6006
# finding cointegration of ['BAT', 'NPXS']
#
# 0.6870713688167508
# 356 / 6006
# finding cointegration of ['BAT', 'NULS']
#
# 0.5191559097140153
# 357 / 6006
# finding cointegration of ['BAT', 'OMG']
#
# 0.14687640861193318
# 358 / 6006
# finding cointegration of ['BAT', 'ONT']
#
# 0.5316094272784841
# 359 / 6006
# finding cointegration of ['BAT', 'QTUM']
#
# 0.44351812701183657
# 360 / 6006
# finding cointegration of ['BAT', 'REP']
#
# 0.5224341288020266
# 361 / 6006
# finding cointegration of ['BAT', 'RLC']
#
# 0.5702082115276154
# 362 / 6006
# finding cointegration of ['BAT', 'SC']
#
# 0.8931961623642253
# 363 / 6006
# finding cointegration of ['BAT', 'SNX']
#
# 0.5163363881305271
# 364 / 6006
# finding cointegration of ['BAT', 'STORJ']
#
# 0.4548277282690557
# 365 / 6006
# finding cointegration of ['BAT', 'STORM']
#
# 0.8294306383861358
# 366 / 6006
# finding cointegration of ['BAT', 'STRAT']
#
# 0.6140331904295143
# 367 / 6006
# finding cointegration of ['BAT', 'STX']
#
# 0.5568835855167577
# 368 / 6006
# finding cointegration of ['BAT', 'THETA']
#
# 0.4015527171213594
# 369 / 6006
# finding cointegration of ['BAT', 'TRX']
#
# 0.38148420892585294
# 370 / 6006
# finding cointegration of ['BAT', 'TUSD']
#
# 0.33145958867274117
# 371 / 6006
# finding cointegration of ['BAT', 'UTK']
#
# 0.9680664490897785
# 372 / 6006
# finding cointegration of ['BAT', 'VEN']
#
# 0.6512019333573146
# 373 / 6006
# finding cointegration of ['BAT', 'WAN']
#
# 0.6091544520467427
# 374 / 6006
# finding cointegration of ['BAT', 'WAVES']
#
# 0.30757965012402433
# 375 / 6006
# finding cointegration of ['BAT', 'WTC']
#
# 0.8925150543037479
# 376 / 6006
# finding cointegration of ['BAT', 'XLM']
#
# 0.430683629858079
# 377 / 6006
# finding cointegration of ['BAT', 'XMR']
#
# 0.2997208648442351
# 378 / 6006
# finding cointegration of ['BAT', 'XRP']
#
# 0.41336623739787454
# 379 / 6006
# finding cointegration of ['BAT', 'XTZ']
#
# 0.6301770853382329
# 380 / 6006
# finding cointegration of ['BAT', 'XZC']
#
# 0.7895366422450812
# 381 / 6006
# finding cointegration of ['BAT', 'ZEC']
#
# 0.03991891594974167
# Added ['BAT', 'ZEC']
#
# 382 / 6006
# finding cointegration of ['BAT', 'ZEN']
#
# 0.9423688627568956
# 383 / 6006
# finding cointegration of ['BAT', 'ZIL']
#
# 0.2771305070653135
# 384 / 6006
# finding cointegration of ['BAT', 'ZRX']
#
# 0.26818733037916476
# 385 / 6006
# finding cointegration of ['BCC', 'ADA']
#
# 0.05321264062387193
# 386 / 6006
# finding cointegration of ['BCC', 'AION']
#
# 0.4398413465966291
# 387 / 6006
# finding cointegration of ['BCC', 'ANT']
#
# 0.3987647416579215
# 388 / 6006
# finding cointegration of ['BCC', 'ARDR']
#
# 0.5821959216698231
# 389 / 6006
# finding cointegration of ['BCC', 'BAT']
#
# 0.2922773976643026
# 390 / 6006
# finding cointegration of ['BCC', 'BCH']
#
# 0.364127181769665
# 391 / 6006
# finding cointegration of ['BCC', 'BLZ']
#
# 0.4991014334561077
# 392 / 6006
# finding cointegration of ['BCC', 'BNB']
#
# 0.23250421945830962
# 393 / 6006
# finding cointegration of ['BCC', 'BNT']
#
# 0.3408918072327555
# 394 / 6006
# finding cointegration of ['BCC', 'BTC']
#
# 0.18679210438349925
# 395 / 6006
# finding cointegration of ['BCC', 'BTS']
#
# 0.49771950064071324
# 396 / 6006
# finding cointegration of ['BCC', 'BUSD']
#
# 0.5759283302773544
# 397 / 6006
# finding cointegration of ['BCC', 'CTXC']
#
# 0.4778445780098704
# 398 / 6006
# finding cointegration of ['BCC', 'CVC']
#
# 0.34023422151191574
# 399 / 6006
# finding cointegration of ['BCC', 'DAI']
#
# 0.19868757124842434
# 400 / 6006
# finding cointegration of ['BCC', 'DASH']
#
# 0.21436198348175411
# 401 / 6006
# finding cointegration of ['BCC', 'DATA']
#
# 0.15535737330881721
# 402 / 6006
# finding cointegration of ['BCC', 'DCR']
#
# 0.26011083601272045
# 403 / 6006
# finding cointegration of ['BCC', 'DENT']
#
# 0.44329084380573314
# 404 / 6006
# finding cointegration of ['BCC', 'DGB']
#
# 0.5833570036957005
# 405 / 6006
# finding cointegration of ['BCC', 'DNT']
#
# 0.19367966970433004
# 406 / 6006
# finding cointegration of ['BCC', 'DOGE']
#
# 0.5054233697674426
# 407 / 6006
# finding cointegration of ['BCC', 'ENJ']
#
# 0.45569309572988786
# 408 / 6006
# finding cointegration of ['BCC', 'EOS']
#
# 0.3669676080490734
# 409 / 6006
# finding cointegration of ['BCC', 'ETC']
#
# 0.20289280412951327
# 410 / 6006
# finding cointegration of ['BCC', 'ETH']
#
# 0.13134031967262233
# 411 / 6006
# finding cointegration of ['BCC', 'FUN']
#
# 0.5794236921186804
# 412 / 6006
# finding cointegration of ['BCC', 'GTO']
#
# 0.23683652856670617
# 413 / 6006
# finding cointegration of ['BCC', 'GXS']
#
# 0.4181249294914824
# 414 / 6006
# finding cointegration of ['BCC', 'ICX']
#
# 0.31869881392604027
# 415 / 6006
# finding cointegration of ['BCC', 'IOST']
#
# 0.20758611302841667
# 416 / 6006
# finding cointegration of ['BCC', 'IOTA']
#
# 0.44070071760880797
# 417 / 6006
# finding cointegration of ['BCC', 'IOTX']
#
# 0.48017694263247246
# 418 / 6006
# finding cointegration of ['BCC', 'KMD']
#
# 0.4635335720074041
# 419 / 6006
# finding cointegration of ['BCC', 'KNC']
#
# 0.03166622857918758
# Added ['BCC', 'KNC']
#
# 420 / 6006
# finding cointegration of ['BCC', 'LEND']
#
# 0.359425597386019
# 421 / 6006
# finding cointegration of ['BCC', 'LINK']
#
# 0.19365242125031118
# 422 / 6006
# finding cointegration of ['BCC', 'LRC']
#
# 0.4738956736543804
# 423 / 6006
# finding cointegration of ['BCC', 'LSK']
#
# 0.554357110885355
# 424 / 6006
# finding cointegration of ['BCC', 'LTC']
#
# 0.2214979214331409
# 425 / 6006
# finding cointegration of ['BCC', 'MANA']
#
# 0.4004090429061501
# 426 / 6006
# finding cointegration of ['BCC', 'MCO']
#
# 0.54147781352156
# 427 / 6006
# finding cointegration of ['BCC', 'MITH']
#
# 0.06343016634195649
# 428 / 6006
# finding cointegration of ['BCC', 'MKR']
#
# 0.38550385902934703
# 429 / 6006
# finding cointegration of ['BCC', 'NANO']
#
# 0.01854999046975261
# Added ['BCC', 'NANO']
#
# 430 / 6006
# finding cointegration of ['BCC', 'NEO']
#
# 0.3013247227116538
# 431 / 6006
# finding cointegration of ['BCC', 'NMR']
#
# 0.4362670387005765
# 432 / 6006
# finding cointegration of ['BCC', 'NPXS']
#
# 0.4523144259876942
# 433 / 6006
# finding cointegration of ['BCC', 'NULS']
#
# 0.5195803433210325
# 434 / 6006
# finding cointegration of ['BCC', 'OMG']
#
# 0.15954273445202588
# 435 / 6006
# finding cointegration of ['BCC', 'ONT']
#
# 0.460646607826696
# 436 / 6006
# finding cointegration of ['BCC', 'QTUM']
#
# 0.13823365367602974
# 437 / 6006
# finding cointegration of ['BCC', 'REP']
#
# 0.010205186986138332
# Added ['BCC', 'REP']
#
# 438 / 6006
# finding cointegration of ['BCC', 'RLC']
#
# 0.48859376375270464
# 439 / 6006
# finding cointegration of ['BCC', 'SC']
#
# 0.11617619623978398
# 440 / 6006
# finding cointegration of ['BCC', 'SNX']
#
# 0.16652161605918187
# 441 / 6006
# finding cointegration of ['BCC', 'STORJ']
#
# 0.2169697140202695
# 442 / 6006
# finding cointegration of ['BCC', 'STORM']
#
# 0.4938480820227942
# 443 / 6006
# finding cointegration of ['BCC', 'STRAT']
#
# 0.17596506223947544
# 444 / 6006
# finding cointegration of ['BCC', 'STX']
#
# 0.5049057617732226
# 445 / 6006
# finding cointegration of ['BCC', 'THETA']
#
# 0.47809866335769863
# 446 / 6006
# finding cointegration of ['BCC', 'TRX']
#
# 0.516124603656752
# 447 / 6006
# finding cointegration of ['BCC', 'TUSD']
#
# 0.5463681203988443
# 448 / 6006
# finding cointegration of ['BCC', 'UTK']
#
# 0.7312174837657832
# 449 / 6006
# finding cointegration of ['BCC', 'VEN']
#
# 0.29380746356474485
# 450 / 6006
# finding cointegration of ['BCC', 'WAN']
#
# 0.5967937358748091
# 451 / 6006
# finding cointegration of ['BCC', 'WAVES']
#
# 0.10000940197538855
# 452 / 6006
# finding cointegration of ['BCC', 'WTC']
#
# 0.2258166684358689
# 453 / 6006
# finding cointegration of ['BCC', 'XLM']
#
# 0.11807578769797045
# 454 / 6006
# finding cointegration of ['BCC', 'XMR']
#
# 0.5847682078361743
# 455 / 6006
# finding cointegration of ['BCC', 'XRP']
#
# 0.23588358828529093
# 456 / 6006
# finding cointegration of ['BCC', 'XTZ']
#
# 0.020115705524028853
# Added ['BCC', 'XTZ']
#
# 457 / 6006
# finding cointegration of ['BCC', 'XZC']
#
# 0.6044118317023998
# 458 / 6006
# finding cointegration of ['BCC', 'ZEC']
#
# 0.4047046249862973
# 459 / 6006
# finding cointegration of ['BCC', 'ZEN']
#
# 0.5102376651633678
# 460 / 6006
# finding cointegration of ['BCC', 'ZIL']
#
# 0.2617458184726946
# 461 / 6006
# finding cointegration of ['BCC', 'ZRX']
#
# 0.560942552130612
# 462 / 6006
# finding cointegration of ['BCH', 'ADA']
#
# 0.3223698060933219
# 463 / 6006
# finding cointegration of ['BCH', 'AION']
#
# 0.4481318025605899
# 464 / 6006
# finding cointegration of ['BCH', 'ANT']
# 0.42987006169216585
# 465 / 6006
# finding cointegration of ['BCH', 'ARDR']
#
# 0.49468275285748614
# 466 / 6006
# finding cointegration of ['BCH', 'BAT']
#
# 0.06651898517379504
# 467 / 6006
# finding cointegration of ['BCH', 'BCC']
#
# 0.28435030620549984
# 468 / 6006
# finding cointegration of ['BCH', 'BLZ']
#
# 0.40074423871058523
# 469 / 6006
# finding cointegration of ['BCH', 'BNB']
#
# 0.22062416387797762
# 470 / 6006
# finding cointegration of ['BCH', 'BNT']
#
# 0.3788098061780482
# 471 / 6006
# finding cointegration of ['BCH', 'BTC']
#
# 0.31922471153221177
# 472 / 6006
# finding cointegration of ['BCH', 'BTS']
#
# 0.23718654127625227
# 473 / 6006
# finding cointegration of ['BCH', 'BUSD']
#
# 0.31125343519415427
# 474 / 6006
# finding cointegration of ['BCH', 'CTXC']
#
# 0.3287460777483051
# 475 / 6006
# finding cointegration of ['BCH', 'CVC']
#
# 0.354908135415671
# 476 / 6006
# finding cointegration of ['BCH', 'DAI']
#
# 0.00045019878336407685
# Added ['BCH', 'DAI']
#
# 477 / 6006
# finding cointegration of ['BCH', 'DASH']
#
# 0.2194354706702582
# 478 / 6006
# finding cointegration of ['BCH', 'DATA']
#
# 0.5332730362976082
# 479 / 6006
# finding cointegration of ['BCH', 'DCR']
#
# 0.6070085023878614
# 480 / 6006
# finding cointegration of ['BCH', 'DENT']
#
# 0.29526442893004357
# 481 / 6006
# finding cointegration of ['BCH', 'DGB']
#
# 0.8165595826348533
# 482 / 6006
# finding cointegration of ['BCH', 'DNT']
#
# 0.800927388039498
# 483 / 6006
# finding cointegration of ['BCH', 'DOGE']
#
# 0.23291409989982453
# 484 / 6006
# finding cointegration of ['BCH', 'ENJ']
#
# 0.3248762653584651
# 485 / 6006
# finding cointegration of ['BCH', 'EOS']
#
# 0.3185632654299453
# 486 / 6006
# finding cointegration of ['BCH', 'ETC']
#
# 0.2988084916768885
# 487 / 6006
# finding cointegration of ['BCH', 'ETH']
#
# 0.2934900521136475
# 488 / 6006
# finding cointegration of ['BCH', 'FUN']
#
# 0.3116484390524227
# 489 / 6006
# finding cointegration of ['BCH', 'GTO']
#
# 0.3126687053320848
# 490 / 6006
# finding cointegration of ['BCH', 'GXS']
#
# 0.6167476343780388
# 491 / 6006
# finding cointegration of ['BCH', 'ICX']
#
# 0.30685279648247277
# 492 / 6006
# finding cointegration of ['BCH', 'IOST']
#
# 0.24267756522615191
# 493 / 6006
# finding cointegration of ['BCH', 'IOTA']
#
# 0.31890991742667596
# 494 / 6006
# finding cointegration of ['BCH', 'IOTX']
#
# 0.3244012377506759
# 495 / 6006
# finding cointegration of ['BCH', 'KMD']
#
# 0.5298248216969922
# 496 / 6006
# finding cointegration of ['BCH', 'KNC']
#
# 0.5777409311597256
# 497 / 6006
# finding cointegration of ['BCH', 'LEND']
#
# 0.7600767593676115
# 498 / 6006
# finding cointegration of ['BCH', 'LINK']
#
# 0.2842175749886565
# 499 / 6006
# finding cointegration of ['BCH', 'LRC']
#
# 0.5642059917901212
# 500 / 6006
# finding cointegration of ['BCH', 'LSK']
#
# 0.2988319997289336
# 501 / 6006
# finding cointegration of ['BCH', 'LTC']
#
# 0.3481390662658841
# 502 / 6006
# finding cointegration of ['BCH', 'MANA']
#
# 0.23059553405487704
# 503 / 6006
# finding cointegration of ['BCH', 'MCO']
#
# 0.14882546210529818
# 504 / 6006
# finding cointegration of ['BCH', 'MITH']
#
# 0.3230861647670599
# 505 / 6006
# finding cointegration of ['BCH', 'MKR']
#
# 0.728514653227275
# 506 / 6006
# finding cointegration of ['BCH', 'NANO']
#
# 0.29664249392775305
# 507 / 6006
# finding cointegration of ['BCH', 'NEO']
#
# 0.33042063854583625
# 508 / 6006
# finding cointegration of ['BCH', 'NMR']
#
# 0.32171801281014034
# 509 / 6006
# finding cointegration of ['BCH', 'NPXS']
#
# 0.28442313238928096
# 510 / 6006
# finding cointegration of ['BCH', 'NULS']
#
# 0.3358793505173641
# 511 / 6006
# finding cointegration of ['BCH', 'OMG']
#
# 0.41409419125648605
# 512 / 6006
# finding cointegration of ['BCH', 'ONT']
#
# 0.291245306592567
# 513 / 6006
# finding cointegration of ['BCH', 'QTUM']
#
# 0.3283647202102024
# 514 / 6006
# finding cointegration of ['BCH', 'REP']
#
# 0.5348447275116436
# 515 / 6006
# finding cointegration of ['BCH', 'RLC']
#
# 0.3364486211980554
# 516 / 6006
# finding cointegration of ['BCH', 'SC']
#
# 0.8453787814711511
# 517 / 6006
# finding cointegration of ['BCH', 'SNX']
#
# 0.5816653584071477
# 518 / 6006
# finding cointegration of ['BCH', 'STORJ']
#
# 0.6931643103026723
# 519 / 6006
# finding cointegration of ['BCH', 'STORM']
#
# 0.43970239765839997
# 520 / 6006
# finding cointegration of ['BCH', 'STRAT']
#
# 0.3574135735673183
# 521 / 6006
# finding cointegration of ['BCH', 'STX']
#
# 0.2613949862186417
# 522 / 6006
# finding cointegration of ['BCH', 'THETA']
#
# 0.3089552766698158
# 523 / 6006
# finding cointegration of ['BCH', 'TRX']
#
# 0.27542110498230743
# 524 / 6006
# finding cointegration of ['BCH', 'TUSD']
#
# 0.3639411243880274
# 525 / 6006
# finding cointegration of ['BCH', 'UTK']
#
# 0.7091654660945378
# 526 / 6006
# finding cointegration of ['BCH', 'VEN']
#
# 0.1929590202916725
# 527 / 6006
# finding cointegration of ['BCH', 'WAN']
#
# 0.3497093087816252
# 528 / 6006
# finding cointegration of ['BCH', 'WAVES']
#
# 0.31948569763748624
# 529 / 6006
# finding cointegration of ['BCH', 'WTC']
#
# 0.5739661510519295
# 530 / 6006
# finding cointegration of ['BCH', 'XLM']
#
# 0.3363301489088305
# 531 / 6006
# finding cointegration of ['BCH', 'XMR']
#
# 0.116417361387598
# 532 / 6006
# finding cointegration of ['BCH', 'XRP']
#
# 0.3092415978383056
# 533 / 6006
# finding cointegration of ['BCH', 'XTZ']
#
# 0.32442679590192025
# 534 / 6006
# finding cointegration of ['BCH', 'XZC']
#
# 0.569566848323015
# 535 / 6006
# finding cointegration of ['BCH', 'ZEC']
#
# 0.2295843526827725
# 536 / 6006
# finding cointegration of ['BCH', 'ZEN']
#
# 0.8135802566980781
# 537 / 6006
# finding cointegration of ['BCH', 'ZIL']
#
# 0.28173373869374874
# 538 / 6006
# finding cointegration of ['BCH', 'ZRX']
#
# 0.2360279079428888
# 539 / 6006
# finding cointegration of ['BLZ', 'ADA']
#
# 0.010749567691496292
# Added ['BLZ', 'ADA']
#
# 540 / 6006
# finding cointegration of ['BLZ', 'AION']
#
# 0.6368878587126717
# 541 / 6006
# finding cointegration of ['BLZ', 'ANT']
#
# 0.06225828910455028
# 542 / 6006
# finding cointegration of ['BLZ', 'ARDR']
#
# 0.27207076557421506
# 543 / 6006
# finding cointegration of ['BLZ', 'BAT']
#
# 0.5661828771765444
# 544 / 6006
# finding cointegration of ['BLZ', 'BCC']
#
# 0.6646639941229371
# 545 / 6006
# finding cointegration of ['BLZ', 'BCH']
#
# 0.310413330364511
# 546 / 6006
# finding cointegration of ['BLZ', 'BNB']
#
# 0.021962375042931245
# Added ['BLZ', 'BNB']
#
# 547 / 6006
# finding cointegration of ['BLZ', 'BNT']
#
# 0.6551577944591046
# 548 / 6006
# finding cointegration of ['BLZ', 'BTC']
#
# 0.5232930551453291
# 549 / 6006
# finding cointegration of ['BLZ', 'BTS']
#
# 0.8381467021608571
# 550 / 6006
# finding cointegration of ['BLZ', 'BUSD']
#
# 0.17510987845842263
# 551 / 6006
# finding cointegration of ['BLZ', 'CTXC']
#
# 0.6592244525273556
# 552 / 6006
# finding cointegration of ['BLZ', 'CVC']
#
# 0.2549604626226155
# 553 / 6006
# finding cointegration of ['BLZ', 'DAI']
#
# 0.4921156115221165
# 554 / 6006
# finding cointegration of ['BLZ', 'DASH']
#
# 0.17627382248267548
# 555 / 6006
# finding cointegration of ['BLZ', 'DATA']
#
# 0.6241230161763857
# 556 / 6006
# finding cointegration of ['BLZ', 'DCR']
#
# 0.5286966158785417
# 557 / 6006
# finding cointegration of ['BLZ', 'DENT']
#
# 0.02562063389183257
# Added ['BLZ', 'DENT']
#
# 558 / 6006
# finding cointegration of ['BLZ', 'DGB']
#
# 0.46092105168617536
# 559 / 6006
# finding cointegration of ['BLZ', 'DNT']
#
# 0.22243414189408134
# 560 / 6006
# finding cointegration of ['BLZ', 'DOGE']
#
# 0.4600053258694465
# 561 / 6006
# finding cointegration of ['BLZ', 'ENJ']
#
# 0.29288163223368724
# 562 / 6006
# finding cointegration of ['BLZ', 'EOS']
#
# 0.02976084219312346
# Added ['BLZ', 'EOS']
#
# 563 / 6006
# finding cointegration of ['BLZ', 'ETC']
#
# 0.033603238501285264
# Added ['BLZ', 'ETC']
#
# 564 / 6006
# finding cointegration of ['BLZ', 'ETH']
#
# 0.6225335512582388
# 565 / 6006
# finding cointegration of ['BLZ', 'FUN']
#
# 0.5248419346914966
# 566 / 6006
# finding cointegration of ['BLZ', 'GTO']
#
# 0.18902169953586917
# 567 / 6006
# finding cointegration of ['BLZ', 'GXS']
#
# 0.29343727524895724
# 568 / 6006
# finding cointegration of ['BLZ', 'ICX']
#
# 0.08075056497631605
# 569 / 6006
# finding cointegration of ['BLZ', 'IOST']
#
# 0.6629417443683515
# 570 / 6006
# finding cointegration of ['BLZ', 'IOTA']
#
# 0.32924743818979185
# 571 / 6006
# finding cointegration of ['BLZ', 'IOTX']
#
# 0.3251075241903141
# 572 / 6006
# finding cointegration of ['BLZ', 'KMD']
#
# 0.11219035446888609
# 573 / 6006
# finding cointegration of ['BLZ', 'KNC']
#
# 0.5347437870210818
# 574 / 6006
# finding cointegration of ['BLZ', 'LEND']
#
# 0.13381084111879615
# 575 / 6006
# finding cointegration of ['BLZ', 'LINK']
#
# 0.41806522453858425
# 576 / 6006
# finding cointegration of ['BLZ', 'LRC']
#
# 0.015268035250232556
# Added ['BLZ', 'LRC']
#
# 577 / 6006
# finding cointegration of ['BLZ', 'LSK']
#
# 0.44692965205781554
# 578 / 6006
# finding cointegration of ['BLZ', 'LTC']
#
# 0.429482469492089
# 579 / 6006
# finding cointegration of ['BLZ', 'MANA']
#
# 0.8401904843049599
# 580 / 6006
# finding cointegration of ['BLZ', 'MCO']
#
# 0.1546922330973715
# 581 / 6006
# finding cointegration of ['BLZ', 'MITH']
#
# 0.33022160336921486
# 582 / 6006
# finding cointegration of ['BLZ', 'MKR']
#
# 0.771760688045005
# 583 / 6006
# finding cointegration of ['BLZ', 'NANO']
#
# 0.30126442873158005
# 584 / 6006
# finding cointegration of ['BLZ', 'NEO']
#
# 0.5720769237174577
# 585 / 6006
# finding cointegration of ['BLZ', 'NMR']
#
# 0.06764066845724026
# 586 / 6006
# finding cointegration of ['BLZ', 'NPXS']
#
# 0.06853549548141265
# 587 / 6006
# finding cointegration of ['BLZ', 'NULS']
#
# 0.30686695016717536
# 588 / 6006
# finding cointegration of ['BLZ', 'OMG']
# 0.5168260648018024
# 589 / 6006
# finding cointegration of ['BLZ', 'ONT']
#
# 0.1599220542987636
# 590 / 6006
# finding cointegration of ['BLZ', 'QTUM']
#
# 0.3273316115670669
# 591 / 6006
# finding cointegration of ['BLZ', 'REP']
#
# 0.6502602898355043
# 592 / 6006
# finding cointegration of ['BLZ', 'RLC']
#
# 0.612722858209716
# 593 / 6006
# finding cointegration of ['BLZ', 'SC']
#
# 0.5399493871501249
# 594 / 6006
# finding cointegration of ['BLZ', 'SNX']
#
# 0.635423716833448
# 595 / 6006
# finding cointegration of ['BLZ', 'STORJ']
#
# 0.5676490545966814
# 596 / 6006
# finding cointegration of ['BLZ', 'STORM']
#
# 0.4421218927560636
# 597 / 6006
# finding cointegration of ['BLZ', 'STRAT']
#
# 0.6894005747044303
# 598 / 6006
# finding cointegration of ['BLZ', 'STX']
#
# 0.323513089846171
# 599 / 6006
# finding cointegration of ['BLZ', 'THETA']
#
# 0.27966237038553454
# 600 / 6006
# finding cointegration of ['BLZ', 'TRX']
#
# 0.0363849280503787
# Added ['BLZ', 'TRX']
#
# 601 / 6006
# finding cointegration of ['BLZ', 'TUSD']
#
# 0.645629354764361
# 602 / 6006
# finding cointegration of ['BLZ', 'UTK']
#
# 0.29020026308939806
# 603 / 6006
# finding cointegration of ['BLZ', 'VEN']
#
# 0.18038449277409135
# 604 / 6006
# finding cointegration of ['BLZ', 'WAN']
#
# 0.5478870895446099
# 605 / 6006
# finding cointegration of ['BLZ', 'WAVES']
#
# 0.5338709271118771
# 606 / 6006
# finding cointegration of ['BLZ', 'WTC']
#
# 0.1332472481005183
# 607 / 6006
# finding cointegration of ['BLZ', 'XLM']
#
# 0.6034498506208092
# 608 / 6006
# finding cointegration of ['BLZ', 'XMR']
#
# 0.03087496166240951
# Added ['BLZ', 'XMR']
#
# 609 / 6006
# finding cointegration of ['BLZ', 'XRP']
#
# 0.24248697398274655
# 610 / 6006
# finding cointegration of ['BLZ', 'XTZ']
#
# 0.005886868661202359
# Added ['BLZ', 'XTZ']
#
# 611 / 6006
# finding cointegration of ['BLZ', 'XZC']
#
# 0.383971448347885
# 612 / 6006
# finding cointegration of ['BLZ', 'ZEC']
#
# 0.13583931441015307
# 613 / 6006
# finding cointegration of ['BLZ', 'ZEN']
#
# 0.19491953650149663
# 614 / 6006
# finding cointegration of ['BLZ', 'ZIL']
#
# 0.6308301616326212
# 615 / 6006
# finding cointegration of ['BLZ', 'ZRX']
#
# 0.3386429860583031
# 616 / 6006
# finding cointegration of ['BNB', 'ADA']
#
# 0.5865595422904833
# 617 / 6006
# finding cointegration of ['BNB', 'AION']
#
# 0.6160015417719068
# 618 / 6006
# finding cointegration of ['BNB', 'ANT']
#
# 0.03461269585567571
# Added ['BNB', 'ANT']
#
# 619 / 6006
# finding cointegration of ['BNB', 'ARDR']
#
# 0.20641281476808615
# 620 / 6006
# finding cointegration of ['BNB', 'BAT']
#
# 0.8527113033879246
# 621 / 6006
# finding cointegration of ['BNB', 'BCC']
#
# 0.2331683987547003
# 622 / 6006
# finding cointegration of ['BNB', 'BCH']
#
# 0.3816331051485855
# 623 / 6006
# finding cointegration of ['BNB', 'BLZ']
#
# 0.041061987119804855
# Added ['BNB', 'BLZ']
#
# 624 / 6006
# finding cointegration of ['BNB', 'BNT']
#
# 0.6127194702272925
# 625 / 6006
# finding cointegration of ['BNB', 'BTC']
#
# 0.43638202767695244
# 626 / 6006
# finding cointegration of ['BNB', 'BTS']
#
# 0.5916472224362693
# 627 / 6006
# finding cointegration of ['BNB', 'BUSD']
#
# 0.05866265378198265
# 628 / 6006
# finding cointegration of ['BNB', 'CTXC']
#
# 0.017015553840130017
# Added ['BNB', 'CTXC']
#
# 629 / 6006
# finding cointegration of ['BNB', 'CVC']
#
# 0.7607543159612633
# 630 / 6006
# finding cointegration of ['BNB', 'DAI']
#
# 1.0
# 631 / 6006
# finding cointegration of ['BNB', 'DASH']
#
# 0.8658635300480977
# 632 / 6006
# finding cointegration of ['BNB', 'DATA']
#
# 0.05007738212769
# 633 / 6006
# finding cointegration of ['BNB', 'DCR']
#
# 0.47415657555483537
# 634 / 6006
# finding cointegration of ['BNB', 'DENT']
#
# 0.1549349883122914
# 635 / 6006
# finding cointegration of ['BNB', 'DGB']
#
# 0.5414324671105822
# 636 / 6006
# finding cointegration of ['BNB', 'DNT']
#
# 0.47600960434108097
# 637 / 6006
# finding cointegration of ['BNB', 'DOGE']
#
# 0.8166640243223523
# 638 / 6006
# finding cointegration of ['BNB', 'ENJ']
#
# 0.5319664471385461
# 639 / 6006
# finding cointegration of ['BNB', 'EOS']
#
# 0.6238396130919244
# 640 / 6006
# finding cointegration of ['BNB', 'ETC']
#
# 0.5925881664212085
# 641 / 6006
# finding cointegration of ['BNB', 'ETH']
#
# 0.8292461412724246
# 642 / 6006
# finding cointegration of ['BNB', 'FUN']
#
# 0.1706597809925119
# 643 / 6006
# finding cointegration of ['BNB', 'GTO']
#
# 0.7792671755169513
# 644 / 6006
# finding cointegration of ['BNB', 'GXS']
#
# 0.037226929866840563
# Added ['BNB', 'GXS']
#
# 645 / 6006
# finding cointegration of ['BNB', 'ICX']
#
# 0.5059014721763865
# 646 / 6006
# finding cointegration of ['BNB', 'IOST']
#
# 0.8808025425976309
# 647 / 6006
# finding cointegration of ['BNB', 'IOTA']
#
# 0.5760815010960996
# 648 / 6006
# finding cointegration of ['BNB', 'IOTX']
#
# 0.26846464381886287
# 649 / 6006
# finding cointegration of ['BNB', 'KMD']
#
# 0.01636726961585276
# Added ['BNB', 'KMD']
#
# 650 / 6006
# finding cointegration of ['BNB', 'KNC']
#
# 0.3308227063737653
# 651 / 6006
# finding cointegration of ['BNB', 'LEND']
#
# 0.09416934245406583
# 652 / 6006
# finding cointegration of ['BNB', 'LINK']
#
# 0.8539565920183566
# 653 / 6006
# finding cointegration of ['BNB', 'LRC']
#
# 0.17138108152365206
# 654 / 6006
# ...
#
# 0.9914227415543906
# 5791 / 6006
# finding cointegration of ['ZEN', 'DASH']
#
# 0.2675525070914483
# 5792 / 6006
# finding cointegration of ['ZEN', 'DATA']
#
# 0.028933878910961157
# Added ['ZEN', 'DATA']
#
# 5793 / 6006
# finding cointegration of ['ZEN', 'DCR']
#
# 0.8787445361209014
# 5794 / 6006
# finding cointegration of ['ZEN', 'DENT']
#
# 0.3240723695316998
# 5795 / 6006
# finding cointegration of ['ZEN', 'DGB']
#
# 1.2925124095774363e-05
# Added ['ZEN', 'DGB']
#
# 5796 / 6006
# finding cointegration of ['ZEN', 'DNT']
#
# 0.6753370411343673
# 5797 / 6006
# finding cointegration of ['ZEN', 'DOGE']
#
# 0.08331769492975122
# 5798 / 6006
# finding cointegration of ['ZEN', 'ENJ']
#
# 0.317312173709855
# 5799 / 6006
# finding cointegration of ['ZEN', 'EOS']
#
# 0.3087624393358994
# 5800 / 6006
# finding cointegration of ['ZEN', 'ETC']
#
# 0.04568617739737646
# Added ['ZEN', 'ETC']
#
# 5801 / 6006
# finding cointegration of ['ZEN', 'ETH']
#
# 0.41984277540551374
# 5802 / 6006
# finding cointegration of ['ZEN', 'FUN']
#
# 0.32808008153227247
# 5803 / 6006
# finding cointegration of ['ZEN', 'GTO']
#
# 0.36087110763877733
# 5804 / 6006
# finding cointegration of ['ZEN', 'GXS']
#
# 0.19820154949960817
# 5805 / 6006
# finding cointegration of ['ZEN', 'ICX']
#
# 0.0442153300062467
# Added ['ZEN', 'ICX']
#
# 5806 / 6006
# finding cointegration of ['ZEN', 'IOST']
#
# 0.09378316679887921
# 5807 / 6006
# finding cointegration of ['ZEN', 'IOTA']
#
# 0.051008949857671536
# 5808 / 6006
# finding cointegration of ['ZEN', 'IOTX']
#
# 0.272392351691116
# 5809 / 6006
# finding cointegration of ['ZEN', 'KMD']
#
# 0.7260361868807161
# 5810 / 6006
# finding cointegration of ['ZEN', 'KNC']
#
# 0.10186429474925524
# 5811 / 6006
# finding cointegration of ['ZEN', 'LEND']
#
# 0.0659763955500488
# 5812 / 6006
# finding cointegration of ['ZEN', 'LINK']
#
# 0.20538401385929084
# 5813 / 6006
# finding cointegration of ['ZEN', 'LRC']
#
# 0.01991301273772488
# Added ['ZEN', 'LRC']
#
# 5814 / 6006
# finding cointegration of ['ZEN', 'LSK']
#
# 0.09053111440777872
# 5815 / 6006
# finding cointegration of ['ZEN', 'LTC']
#
# 0.3677914534518154
# 5816 / 6006
# finding cointegration of ['ZEN', 'MANA']
#
# 0.7703529118700085
# 5817 / 6006
# finding cointegration of ['ZEN', 'MCO']
#
# 0.32929189732287084
# 5818 / 6006
# finding cointegration of ['ZEN', 'MITH']
#
# 0.35063697921786513
# 5819 / 6006
# finding cointegration of ['ZEN', 'MKR']
#
# 0.4028554573752842
# 5820 / 6006
# finding cointegration of ['ZEN', 'NANO']
#
# 0.3695605877894909
# 5821 / 6006
# finding cointegration of ['ZEN', 'NEO']
#
# 0.3536241723269393
# 5822 / 6006
# finding cointegration of ['ZEN', 'NMR']
#
# 0.7862195129426273
# 5823 / 6006
# finding cointegration of ['ZEN', 'NPXS']
#
# 0.31559178126958826
# 5824 / 6006
# finding cointegration of ['ZEN', 'NULS']
#
# 0.09446513894019698
# 5825 / 6006
# finding cointegration of ['ZEN', 'OMG']
#
# 0.26974543295403064
# 5826 / 6006
# finding cointegration of ['ZEN', 'ONT']
#
# 0.3315576946296378
# 5827 / 6006
# finding cointegration of ['ZEN', 'QTUM']
#
# 0.3379261125677655
# 5828 / 6006
# finding cointegration of ['ZEN', 'REP']
#
# 0.0809930406637468
# 5829 / 6006
# finding cointegration of ['ZEN', 'RLC']
#
# 0.07508407890231149
# 5830 / 6006
# finding cointegration of ['ZEN', 'SC']
# 0.43357608766905836
# 5831 / 6006
# finding cointegration of ['ZEN', 'SNX']
#
# 0.13629993059524287
# 5832 / 6006
# finding cointegration of ['ZEN', 'STORJ']
#
# 0.7797067951406191
# 5833 / 6006
# finding cointegration of ['ZEN', 'STORM']
#
# 0.12401006595656511
# 5834 / 6006
# finding cointegration of ['ZEN', 'STRAT']
#
# 0.2519473704983508
# 5835 / 6006
# finding cointegration of ['ZEN', 'STX']
#
# 0.5757996595427342
# 5836 / 6006
# finding cointegration of ['ZEN', 'THETA']
#
# 0.405664678092968
# 5837 / 6006
# finding cointegration of ['ZEN', 'TRX']
#
# 0.32023477299448366
# 5838 / 6006
# finding cointegration of ['ZEN', 'TUSD']
#
# 0.34806375382088617
# 5839 / 6006
# finding cointegration of ['ZEN', 'UTK']
#
# 0.6252087673264947
# 5840 / 6006
# finding cointegration of ['ZEN', 'VEN']
#
# 0.11505240806980432
# 5841 / 6006
# finding cointegration of ['ZEN', 'WAN']
#
# 0.3549067117127393
# 5842 / 6006
# finding cointegration of ['ZEN', 'WAVES']
#
# 0.38830476459678315
# 5843 / 6006
# finding cointegration of ['ZEN', 'WTC']
#
# 0.35181962336634004
# 5844 / 6006
# finding cointegration of ['ZEN', 'XLM']
#
# 0.06721931980277256
# 5845 / 6006
# finding cointegration of ['ZEN', 'XMR']
#
# 0.21194449389700537
# 5846 / 6006
# finding cointegration of ['ZEN', 'XRP']
#
# 0.17367523994953227
# 5847 / 6006
# finding cointegration of ['ZEN', 'XTZ']
#
# 0.6196427341584404
# 5848 / 6006
# finding cointegration of ['ZEN', 'XZC']
#
# 0.07153777464760372
# 5849 / 6006
# finding cointegration of ['ZEN', 'ZEC']
#
# 0.11552458566729024
# 5850 / 6006
# finding cointegration of ['ZEN', 'ZIL']
#
# 0.469126691240974
# 5851 / 6006
# finding cointegration of ['ZEN', 'ZRX']
#
# 0.34143966078381993
# 5852 / 6006
# finding cointegration of ['ZIL', 'ADA']
#
# 0.22965306504962485
# 5853 / 6006
# finding cointegration of ['ZIL', 'AION']
#
# 0.8711857493899857
# 5854 / 6006
# finding cointegration of ['ZIL', 'ANT']
#
# 0.14271704363277876
# 5855 / 6006
# finding cointegration of ['ZIL', 'ARDR']
#
# 0.657800132255143
# 5856 / 6006
# finding cointegration of ['ZIL', 'BAT']
#
# 0.5487148126679022
# 5857 / 6006
# finding cointegration of ['ZIL', 'BCC']
#
# 0.551627395466724
# 5858 / 6006
# finding cointegration of ['ZIL', 'BCH']
#
# 0.9149343697655554
# 5859 / 6006
# finding cointegration of ['ZIL', 'BLZ']
#
# 0.3104134565529844
# 5860 / 6006
# finding cointegration of ['ZIL', 'BNB']
#
# 0.27648733573184675
# 5861 / 6006
# finding cointegration of ['ZIL', 'BNT']
#
# 0.5843842079257147
# 5862 / 6006
# finding cointegration of ['ZIL', 'BTC']
#
# 0.030829167828902
# Added ['ZIL', 'BTC']
#
# 5863 / 6006
# finding cointegration of ['ZIL', 'BTS']
#
# 0.811201088661132
# 5864 / 6006
# finding cointegration of ['ZIL', 'BUSD']
#
# 0.9137342041154048
# 5865 / 6006
# finding cointegration of ['ZIL', 'CTXC']
#
# 0.8958627612451115
# 5866 / 6006
# finding cointegration of ['ZIL', 'CVC']
#
# 0.8925035483572152
# 5867 / 6006
# finding cointegration of ['ZIL', 'DAI']
#
# 0.8068358149410428
# 5868 / 6006
# finding cointegration of ['ZIL', 'DASH']
#
# 0.5428840286833013
# 5869 / 6006
# finding cointegration of ['ZIL', 'DATA']
#
# 0.30976361027414123
# 5870 / 6006
# finding cointegration of ['ZIL', 'DCR']
#
# 0.2432298936768576
# 5871 / 6006
# finding cointegration of ['ZIL', 'DENT']
#
# 0.722855936714594
# 5872 / 6006
# finding cointegration of ['ZIL', 'DGB']
#
# 0.044861668055714676
# Added ['ZIL', 'DGB']
#
# 5873 / 6006
# finding cointegration of ['ZIL', 'DNT']
#
# 0.002781093489954306
# Added ['ZIL', 'DNT']
#
# 5874 / 6006
# finding cointegration of ['ZIL', 'DOGE']
#
# 0.6663875124751043
# 5875 / 6006
# finding cointegration of ['ZIL', 'ENJ']
#
# 0.622525926368479
# 5876 / 6006
# finding cointegration of ['ZIL', 'EOS']
#
# 0.25490446498272634
# 5877 / 6006
# finding cointegration of ['ZIL', 'ETC']
#
# 0.14422702914946672
# 5878 / 6006
# finding cointegration of ['ZIL', 'ETH']
#
# 0.09293283602890429
# 5879 / 6006
# finding cointegration of ['ZIL', 'FUN']
#
# 0.882250954627014
# 5880 / 6006
# finding cointegration of ['ZIL', 'GTO']
#
# 0.48605756925368154
# 5881 / 6006
# finding cointegration of ['ZIL', 'GXS']
#
# 0.29257479651505125
# 5882 / 6006
# finding cointegration of ['ZIL', 'ICX']
#
# 0.22063918838413182
# 5883 / 6006
# finding cointegration of ['ZIL', 'IOST']
#
# 0.31372896568520187
# 5884 / 6006
# finding cointegration of ['ZIL', 'IOTA']
#
# 0.200953963253651
# 5885 / 6006
# finding cointegration of ['ZIL', 'IOTX']
#
# 0.5685896975921412
# 5886 / 6006
# finding cointegration of ['ZIL', 'KMD']
#
# 0.3231704578845205
# 5887 / 6006
# finding cointegration of ['ZIL', 'KNC']
#
# 0.42103345254048974
# 5888 / 6006
# finding cointegration of ['ZIL', 'LEND']
#
# 0.10530552159366513
# 5889 / 6006
# finding cointegration of ['ZIL', 'LINK']
#
# 0.47340235600598896
# 5890 / 6006
# finding cointegration of ['ZIL', 'LRC']
#
# 0.4201011633055469
# 5891 / 6006
# finding cointegration of ['ZIL', 'LSK']
#
# 0.8361702409355536
# 5892 / 6006
# finding cointegration of ['ZIL', 'LTC']
#
# 0.11326116685895599
# 5893 / 6006
# finding cointegration of ['ZIL', 'MANA']
#
# 0.36930841747278736
# 5894 / 6006
# finding cointegration of ['ZIL', 'MCO']
#
# 0.8354998777958889
# 5895 / 6006
# finding cointegration of ['ZIL', 'MITH']
#
# 0.455385098123929
# 5896 / 6006
# finding cointegration of ['ZIL', 'MKR']
#
# 0.19444963396127596
# 5897 / 6006
# finding cointegration of ['ZIL', 'NANO']
#
# 0.3975414944884794
# 5898 / 6006
# finding cointegration of ['ZIL', 'NEO']
#
# 0.03429165641301644
# Added ['ZIL', 'NEO']
#
# 5899 / 6006
# finding cointegration of ['ZIL', 'NMR']
#
# 0.22861697612624515
# 5900 / 6006
# finding cointegration of ['ZIL', 'NPXS']
#
# 0.4422156987058116
# 5901 / 6006
# finding cointegration of ['ZIL', 'NULS']
#
# 0.298495690634173
# 5902 / 6006
# finding cointegration of ['ZIL', 'OMG']
#
# 0.23242739208592494
# 5903 / 6006
# finding cointegration of ['ZIL', 'ONT']
#
# 0.2267842009414594
# 5904 / 6006
# finding cointegration of ['ZIL', 'QTUM']
#
# 0.1956133449329795
# 5905 / 6006
# finding cointegration of ['ZIL', 'REP']
#
# 0.41524823702006486
# 5906 / 6006
# finding cointegration of ['ZIL', 'RLC']
#
# 0.7451206994573387
# 5907 / 6006
# finding cointegration of ['ZIL', 'SC']
#
# 0.23910780529662395
# 5908 / 6006
# finding cointegration of ['ZIL', 'SNX']
#
# 0.16793681331102955
# 5909 / 6006
# finding cointegration of ['ZIL', 'STORJ']
#
# 0.28362813450512775
# 5910 / 6006
# finding cointegration of ['ZIL', 'STORM']
#
# 0.8723876517434475
# 5911 / 6006
# finding cointegration of ['ZIL', 'STRAT']
#
# 0.59771000152341
# 5912 / 6006
# finding cointegration of ['ZIL', 'STX']
#
# 0.9841317613699299
# 5913 / 6006
# finding cointegration of ['ZIL', 'THETA']
#
# 0.7398613060972582
# 5914 / 6006
# finding cointegration of ['ZIL', 'TRX']
#
# 0.5312468599454869
# 5915 / 6006
# finding cointegration of ['ZIL', 'TUSD']
#
# 0.2909840625729997
# 5916 / 6006
# finding cointegration of ['ZIL', 'UTK']
#
# 0.6735621589636114
# 5917 / 6006
# finding cointegration of ['ZIL', 'VEN']
#
# 0.5257419389627401
# 5918 / 6006
# finding cointegration of ['ZIL', 'WAN']
#
# 0.891868477399963
# 5919 / 6006
# finding cointegration of ['ZIL', 'WAVES']
#
# 0.05468729572244005
# 5920 / 6006
# finding cointegration of ['ZIL', 'WTC']
#
# 0.7853615148366611
# 5921 / 6006
# finding cointegration of ['ZIL', 'XLM']
#
# 0.25477818934724034
# 5922 / 6006
# finding cointegration of ['ZIL', 'XMR']
#
# 0.4458975033781073
# 5923 / 6006
# finding cointegration of ['ZIL', 'XRP']
#
# 0.39213242089571343
# 5924 / 6006
# finding cointegration of ['ZIL', 'XTZ']
#
# 0.36601636487983147
# 5925 / 6006
# finding cointegration of ['ZIL', 'XZC']
#
# 0.7192236511648582
# 5926 / 6006
# finding cointegration of ['ZIL', 'ZEC']
#
# 0.10604552777100507
# 5927 / 6006
# finding cointegration of ['ZIL', 'ZEN']
#
# 0.17509980079266657
# 5928 / 6006
# finding cointegration of ['ZIL', 'ZRX']
#
# 0.42143391681875686
# 5929 / 6006
# finding cointegration of ['ZRX', 'ADA']
#
# 0.2691040723867842
# 5930 / 6006
# finding cointegration of ['ZRX', 'AION']
#
# 0.17254520395292122
# 5931 / 6006
# finding cointegration of ['ZRX', 'ANT']
#
# 0.08664754940196095
# 5932 / 6006
# finding cointegration of ['ZRX', 'ARDR']
#
# 0.6867418793369571
# 5933 / 6006
# finding cointegration of ['ZRX', 'BAT']
#
# 0.4055897427217737
# 5934 / 6006
# finding cointegration of ['ZRX', 'BCC']
#
# 0.5294758968450124
# 5935 / 6006
# finding cointegration of ['ZRX', 'BCH']
#
# 0.36519247221444595
# 5936 / 6006
# finding cointegration of ['ZRX', 'BLZ']
#
# 0.4379011072277699
# 5937 / 6006
# finding cointegration of ['ZRX', 'BNB']
#
# 0.2396289996934166
# 5938 / 6006
# finding cointegration of ['ZRX', 'BNT']
#
# 0.10565470049656656
# 5939 / 6006
# finding cointegration of ['ZRX', 'BTC']
#
# 0.08017047381893011
# 5940 / 6006
# finding cointegration of ['ZRX', 'BTS']
#
# 0.2837769822422479
# 5941 / 6006
# finding cointegration of ['ZRX', 'BUSD']
#
# 0.03343453121335401
# Added ['ZRX', 'BUSD']
#
# 5942 / 6006
# finding cointegration of ['ZRX', 'CTXC']
#
# 0.11719245541139617
# 5943 / 6006
# finding cointegration of ['ZRX', 'CVC']
#
# 0.14218882685034345
# 5944 / 6006
# finding cointegration of ['ZRX', 'DAI']
#
# 0.955020452488635
# 5945 / 6006
# finding cointegration of ['ZRX', 'DASH']
# 0.44763864318814806
# 5946 / 6006
# finding cointegration of ['ZRX', 'DATA']
#
# 0.47227299992250993
# 5947 / 6006
# finding cointegration of ['ZRX', 'DCR']
#
# 0.7227914990196391
# 5948 / 6006
# finding cointegration of ['ZRX', 'DENT']
#
# 0.15672626086227315
# 5949 / 6006
# finding cointegration of ['ZRX', 'DGB']
#
# 0.49950385103857525
# 5950 / 6006
# finding cointegration of ['ZRX', 'DNT']
#
# 0.4241695606359437
# 5951 / 6006
# finding cointegration of ['ZRX', 'DOGE']
#
# 0.19022962233008167
# 5952 / 6006
# finding cointegration of ['ZRX', 'ENJ']
#
# 0.38022318978014896
# 5953 / 6006
# finding cointegration of ['ZRX', 'EOS']
#
# 0.35485526812927926
# 5954 / 6006
# finding cointegration of ['ZRX', 'ETC']
#
# 0.27435515625869994
# 5955 / 6006
# finding cointegration of ['ZRX', 'ETH']
#
# 0.2756211092029837
# 5956 / 6006
# finding cointegration of ['ZRX', 'FUN']
#
# 0.15423466038696937
# 5957 / 6006
# finding cointegration of ['ZRX', 'GTO']
#
# 0.14057283760018108
# 5958 / 6006
# finding cointegration of ['ZRX', 'GXS']
#
# 0.09892411121252398
# 5959 / 6006
# finding cointegration of ['ZRX', 'ICX']
#
# 0.25623014815895806
# 5960 / 6006
# finding cointegration of ['ZRX', 'IOST']
#
# 0.28239986321556143
# 5961 / 6006
# finding cointegration of ['ZRX', 'IOTA']
#
# 0.27415753636366486
# 5962 / 6006
# finding cointegration of ['ZRX', 'IOTX']
#
# 0.2066043514102458
# 5963 / 6006
# finding cointegration of ['ZRX', 'KMD']
#
# 0.19665082692271801
# 5964 / 6006
# finding cointegration of ['ZRX', 'KNC']
#
# 0.5706905041351016
# 5965 / 6006
# finding cointegration of ['ZRX', 'LEND']
#
# 0.3815397537598778
# 5966 / 6006
# finding cointegration of ['ZRX', 'LINK']
#
# 0.09419570244849274
# 5967 / 6006
# finding cointegration of ['ZRX', 'LRC']
#
# 0.5059845138233249
# 5968 / 6006
# finding cointegration of ['ZRX', 'LSK']
#
# 0.3925535534753851
# 5969 / 6006
# finding cointegration of ['ZRX', 'LTC']
#
# 0.2607775983850008
# 5970 / 6006
# finding cointegration of ['ZRX', 'MANA']
#
# 0.8246700339990203
# 5971 / 6006
# finding cointegration of ['ZRX', 'MCO']
#
# 0.4731040254114045
# 5972 / 6006
# finding cointegration of ['ZRX', 'MITH']
#
# 0.34045064477328724
# 5973 / 6006
# finding cointegration of ['ZRX', 'MKR']
#
# 0.45078864804235186
# 5974 / 6006
# finding cointegration of ['ZRX', 'NANO']
#
# 0.45586900828368176
# 5975 / 6006
# finding cointegration of ['ZRX', 'NEO']
#
# 0.27217910991289734
# 5976 / 6006
# finding cointegration of ['ZRX', 'NMR']
#
# 0.2528326259200612
# 5977 / 6006
# finding cointegration of ['ZRX', 'NPXS']
#
# 0.18219276028810039
# 5978 / 6006
# finding cointegration of ['ZRX', 'NULS']
#
# 0.2411741408206327
# 5979 / 6006
# finding cointegration of ['ZRX', 'OMG']
#
# 0.0013291799074485434
# Added ['ZRX', 'OMG']
#
# 5980 / 6006
# finding cointegration of ['ZRX', 'ONT']
#
# 0.28383419687582007
# 5981 / 6006
# finding cointegration of ['ZRX', 'QTUM']
#
# 0.26897852864333405
# 5982 / 6006
# finding cointegration of ['ZRX', 'REP']
#
# 0.4133137140205263
# 5983 / 6006
# finding cointegration of ['ZRX', 'RLC']
#
# 0.22161722329871852
# 5984 / 6006
# finding cointegration of ['ZRX', 'SC']
#
# 0.6090656592887758
# 5985 / 6006
# finding cointegration of ['ZRX', 'SNX']
#
# 0.47177872376261665
# 5986 / 6006
# finding cointegration of ['ZRX', 'STORJ']
#
# 0.4820047762443223
# 5987 / 6006
# finding cointegration of ['ZRX', 'STORM']
#
# 0.6974382943856297
# 5988 / 6006
# finding cointegration of ['ZRX', 'STRAT']
#
# 0.024633364469622224
# Added ['ZRX', 'STRAT']
#
# 5989 / 6006
# finding cointegration of ['ZRX', 'STX']
#
# 0.535103645268666
# 5990 / 6006
# finding cointegration of ['ZRX', 'THETA']
#
# 0.04164519089763538
# Added ['ZRX', 'THETA']
#
# 5991 / 6006
# finding cointegration of ['ZRX', 'TRX']
#
# 0.23017412771570855
# 5992 / 6006
# finding cointegration of ['ZRX', 'TUSD']
#
# 0.30750845561489726
# 5993 / 6006
# finding cointegration of ['ZRX', 'UTK']
#
# 0.7925162181028607
# 5994 / 6006
# finding cointegration of ['ZRX', 'VEN']
#
# 0.011158286471365955
# Added ['ZRX', 'VEN']
#
# 5995 / 6006
# finding cointegration of ['ZRX', 'WAN']
#
# 0.13616275523398447
# 5996 / 6006
# finding cointegration of ['ZRX', 'WAVES']
#
# 0.24046524169312278
# 5997 / 6006
# finding cointegration of ['ZRX', 'WTC']
#
# 0.641210626447976
# 5998 / 6006
# finding cointegration of ['ZRX', 'XLM']
#
# 0.24112381050483972
# 5999 / 6006
# finding cointegration of ['ZRX', 'XMR']
#
# 0.1350553061841473
# 6000 / 6006
# finding cointegration of ['ZRX', 'XRP']
#
# 0.2395429021138853
# 6001 / 6006
# finding cointegration of ['ZRX', 'XTZ']
#
# 0.09127418619521166
# 6002 / 6006
# finding cointegration of ['ZRX', 'XZC']
#
# 0.5505289319776827
# 6003 / 6006
# finding cointegration of ['ZRX', 'ZEC']
#
# 0.2740122301161985
# 6004 / 6006
# finding cointegration of ['ZRX', 'ZEN']
#
# 0.42813706731252643
# 6005 / 6006
# finding cointegration of ['ZRX', 'ZIL']
#
# 0.22481749399154227

# %%
df = pd.DataFrame.from_dict(selected_pairs)
filename = "Cointegrated Pairs.csv"
df.to_csv(filename, index=False)
